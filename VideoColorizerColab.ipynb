# %% [markdown]
# <a href="https://colab.research.google.com/github/sodiqdevpython/3d-models-version-1.0/blob/main/VideoColorizerColab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### **<font color='blue'> Video Colorizer </font>**

# %%
# !git clone https://github.com/jantic/DeOldify.git DeOldify
# Out:
# fatal: destination path 'DeOldify' already exists and is not an empty directory.

# %%
cd DeOldify
# Out:
# /content/DeOldify

# %%
#NOTE:  This must be the first call in order to work properly!
from deoldify import device
from deoldify.device_id import DeviceId
#choices:  CPU, GPU0...GPU7
device.set(device=DeviceId.GPU0)

import torch

if not torch.cuda.is_available():
    print('GPU not available.')

from os import path

# %%
# !pip install -r requirements-colab.txt

# %%
import fastai
from deoldify.visualize import *
from pathlib import Path
torch.backends.cudnn.benchmark=True
import warnings
warnings.filterwarnings("ignore", category=UserWarning, message=".*?Your .*? set is empty.*?")
# Out:
# INFO:numexpr.utils:NumExpr defaulting to 2 threads.
# NumExpr defaulting to 2 threads.

# %%
# !mkdir 'models'
# !wget https://data.deepai.org/deoldify/ColorizeVideo_gen.pth -O ./models/ColorizeVideo_gen.pth
# Out:
# mkdir: cannot create directory ‘models’: File exists
# --2025-03-12 02:25:48--  https://data.deepai.org/deoldify/ColorizeVideo_gen.pth
# Resolving data.deepai.org (data.deepai.org)... 143.244.50.88, 2400:52e0:1a01::1115:1
# Connecting to data.deepai.org (data.deepai.org)|143.244.50.88|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 874066230 (834M) [application/octet-stream]
# Saving to: ‘./models/ColorizeVideo_gen.pth’
#
# ./models/ColorizeVi 100%[===================>] 833.57M  4.95MB/s    in 2m 51s
#
# 2025-03-12 02:28:39 (4.86 MB/s) - ‘./models/ColorizeVideo_gen.pth’ saved [874066230/874066230]

# %%
# !wget https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth -O ./models/ColorizeArtistic_gen.pth
# Out:
# --2025-03-12 02:29:00--  https://data.deepai.org/deoldify/ColorizeArtistic_gen.pth
# Resolving data.deepai.org (data.deepai.org)... 143.244.49.178, 2400:52e0:1a01::1112:1
# Connecting to data.deepai.org (data.deepai.org)|143.244.49.178|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 255144681 (243M) [application/octet-stream]
# Saving to: ‘./models/ColorizeArtistic_gen.pth’
#
# ./models/ColorizeAr 100%[===================>] 243.32M  4.95MB/s    in 56s
#
# 2025-03-12 02:29:57 (4.33 MB/s) - ‘./models/ColorizeArtistic_gen.pth’ saved [255144681/255144681]
# ...

# %%
colorizer = get_video_colorizer()
# Out:
# /usr/local/lib/python3.11/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# ...

# %%
import torch
if not torch.cuda.is_available():
    print("GPU yoqilmagan! Runtime type → GPU qilib o‘zgartiring.")

from deoldify.visualize import get_image_colorizer

colorizer = get_image_colorizer(artistic=True)

image_path = '/content/123.jpeg'

colorizer.plot_transformed_image(image_path, render_factor=21, display_render_factor=True)
# Out:
# PosixPath('result_images/123.jpeg')

# %%
colorizer = get_video_colorizer()

video_path = "/content/video.mp4"
colorizer.colorize_from_file_name(video_path, render_factor=21)
# Out:
# /usr/local/lib/python3.11/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet101_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet101_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
# ...
